# %%
import os 
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
groq_model = ChatGroq("llama-3.3-70b-versatile")

groq_model

# %%
response = groq_model.invoke({"messages": "What is the weather in Hyderabad?"})

response

# %%
from langchain_openai import ChatOpenAI
openai_model = ChatOpenAI("gpt-4o")

openai_model

# %%
response = openai_model.invoke({"messages": "What is the weather in Hyderabad?"})

response

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
gemini_model = ChatGoogleGenerativeAI("gemini-1.5-turbo")

gemini_model

# %%
response = gemini_model.invoke({"messages": "What is the weather in Hyderabad?"})

response
